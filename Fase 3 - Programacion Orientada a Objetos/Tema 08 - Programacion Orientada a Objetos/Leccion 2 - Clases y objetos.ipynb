# %%
# la clase es un molde para crear objetos
class Galleta: 
    pass

# %%
una_galleta = Galleta()
otra_galleta = Galleta()

# %%
type(una_galleta)
# Out:
# __main__.Galleta

# %%
type(10)
# Out:
# int

# %%
type(3.24)
# Out:
# float

# %%
type("Hola")
# Out:
# str

# %%
type([])
# Out:
# list

# %%
type({})
# Out:
# dict

# %%
type(True)
# Out:
# bool

# %%
def hola():
    pass
type(hola)
# Out:
# function
