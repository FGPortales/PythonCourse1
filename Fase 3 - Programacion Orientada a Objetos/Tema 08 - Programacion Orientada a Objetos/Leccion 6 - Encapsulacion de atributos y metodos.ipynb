# %%
class Ejemplo:
    __artibuto__privado = "Soy un atributo inalcanzable desde fuera"
    
    def __metodo_privado(self):
        print("Soy un método inalcanzable desde fuera")

# %%
e = Ejemplo()

# %%
e.__atributo_privado
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-f7d87cbc25da> in <module>
# ----> 1 e.__atributo_privado
#
# AttributeError: 'Ejemplo' object has no attribute '__atributo_privado'

# %%
e.__metodo_privado()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-81c514698440> in <module>
# ----> 1 e.__metodo_privado()
#
# AttributeError: 'Ejemplo' object has no attribute '__metodo_privado'

# %%
class Ejemplo:
    __atributo_privado = "Soy un atributo inalcanzable desde fuera"
    
    def __metodo_privado(self):
        print("Soy un método inalcanzable desde fuera")
        
    def atributo_publico(self):
        return self.__atributo_privado
    
    def metodo_publico(self):
        return self.__metodo_privado()

# %%
e = Ejemplo()

# %%
e.metodo_publico()
# Out:
# Soy un método inalcanzable desde fuera
