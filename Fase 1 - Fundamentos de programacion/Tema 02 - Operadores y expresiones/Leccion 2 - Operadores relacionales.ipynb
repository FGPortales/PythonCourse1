# %%
# igual que
3 == 2
# Out:
# False

# %%
# distinto de
3 != 2
# Out:
# True

# %%
'hola' == 'hola1'
# Out:
# False

# %%
# mayor que 
3 > 2
# Out:
# True

# %%
# menor que 
3 < 2
# Out:
# False

# %%
# mayor o igual que
3 >= 2
# Out:
# True

# %%
# menor o igual que 
3 <= 1
# Out:
# False

# %%
a = 10
b = 5
c = 1/2
a > b
# Out:
# True

# %%
b != a
# Out:
# True

# %%
a == b*2
# Out:
# True

# %%
b == a*c
# Out:
# True

# %%
"hola" == "hola"
# Out:
# True

# %%
"hola" != "hola"
# Out:
# False

# %%
c = "hola"
c[0] == "h"
# Out:
# True

# %%
c[-1] == "a"
# Out:
# True

# %%
l1 = [0,1,2]
l2 = [2,3,4]
l1 == l2
# Out:
# False

# %%
len(l1) == len(l2)
# Out:
# True

# %%
l1[-1] == l2[0]
# Out:
# True

# %%
True == True
# Out:
# True

# %%
False == False
# Out:
# True

# %%
False != True
# Out:
# True

# %%
True > False
# Out:
# True

# %%
False > True
# Out:
# False

# %%
True * 3
# Out:
# 3

# %%
False * 3
# Out:
# 0

# %%
True * False
# Out:
# 0

# %%
True + False
# Out:
# 1

# %%
True + True
# Out:
# 2
