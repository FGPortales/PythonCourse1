# %%
decimal = float(input("Introduce un numero decimal con punto: "))
# Out:
# Introduce un numero decimal con punto: 3.14

# %%
valores = []

# %%
print("Introduce 3 valores")

for x in range(3):
    valores.append(int(input("Introduce un valor: ")))
# Out:
# Introduce 3 valores
# Introduce un valor: 6
# Introduce un valor: 7
# Introduce un valor: 8

# %%
print(valores)
# Out:
# ['5', '6', '1', 6, 7, 8]
