# %%
def mi_funcion(algo=None):
    if algo is None:
        print("Error! No se permite un valor nulo")
    
mi_funcion("algo")

# %%
mi_funcion()
# Out:
# Error! No se permite un valor nulo

# %%
def mi_funcion(algo=None):
    try:
        if algo is None:
            raise ValueError("Error! No se permite un valor nulo") # invocar un valueError (se lanza un error manualmente)
    except ValueError:
        print("Error! No se permite un valor nulo1") 

mi_funcion()
# Out:
# Error! No se permite un valor nulo1

# %%
def mi_funcion(algo=None):
        if algo is None:
            raise ValueError("Error! No se permite un valor nulo")
mi_funcion()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-a96d24313a2b> in <module>
#       2         if algo is None:
#       3             raise ValueError("Error! No se permite un valor nulo")
# ----> 4 mi_funcion()
#
# <ipython-input-9-a96d24313a2b> in mi_funcion(algo)
#       1 def mi_funcion(algo=None):
#       2         if algo is None:
# ----> 3             raise ValueError("Error! No se permite un valor nulo")
#       4 mi_funcion()
#
# ValueError: Error! No se permite un valor nulo
