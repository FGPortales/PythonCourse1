# %%
print("Hola"
# Out:
#   File "<ipython-input-1-b05437ee445f>", line 1
#     print("Hola"
#                 ^
# SyntaxError: unexpected EOF while parsing

# %%
pint("Hola")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2306e95e3727> in <module>
# ----> 1 pint("Hola")
#
# NameError: name 'pint' is not defined

# %%
l = [1,2,3]

# %%
l.pop()
l.pop()
l.pop()
# Out:
# 1

# %%
l
# Out:
# []

# %%
l.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-33a5ac1f2384> in <module>
# ----> 1 l.pop()
#
# IndexError: pop from empty list

# %%
l = [1,2,3]

# %%
if len(l) > 0:
    l.pop()

# %%
l
# Out:
# []

# %%
n = input("Introduce un número: ")
# Out:
# Introduce un número: 4

# %%
m = 4

# %%
print("{}/{}={}".format(n,m,n/m))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-66c32f9fdef2> in <module>
# ----> 1 print("{}/{}={}".format(n,m,n/m))
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
n = float(input("Introduce un número: "))
m = 4
print("{}/{}={}".format(n,m,n/m))
# Out:
# Introduce un número: aaa
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-59961d56dfa0> in <module>
# ----> 1 n = float(input("Introduce un número: "))
#       2 m = 4
#       3 print("{}/{}={}".format(n,m,n/m))
#
# ValueError: could not convert string to float: 'aaa'
