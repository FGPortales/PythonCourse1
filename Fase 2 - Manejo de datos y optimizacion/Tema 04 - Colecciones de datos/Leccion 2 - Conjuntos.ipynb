# %%
conjunto = set()

# %%
conjunto
# Out:
# set()

# %%
conjunto = {1,2,3}

# %%
conjunto
# Out:
# {1, 2, 3}

# %%
conjunto.add(4)
conjunto
# Out:
# {1, 2, 3, 4}

# %%
conjunto.add(0)
conjunto
# Out:
# {0, 1, 2, 3, 4}

# %%
conjunto.add("h")
conjunto
# Out:
# {0, 1, 2, 3, 4, 'h'}

# %%
conjunto.add("b")
conjunto
# Out:
# {0, 1, 2, 3, 4, 'b', 'h'}

# %%
conjunto.add("z")
conjunto
# Out:
# {0, 1, 2, 3, 4, 'b', 'h', 'z'}

# %%
conjunto.add("x")
conjunto
# Out:
# {0, 1, 2, 3, 4, 'b', 'h', 'x', 'z'}

# %%
conjunto.add("c")
conjunto
# Out:
# {0, 1, 2, 3, 4, 'b', 'c', 'h', 'x', 'z'}

# %%
conjunto.add(20)
conjunto
# Out:
# {0, 1, 2, 20, 3, 4, 'b', 'c', 'h', 'x', 'z'}

# %%
conjunto.add(10)
conjunto
# Out:
# {0, 1, 10, 2, 20, 3, 4, 'b', 'c', 'h', 'x', 'z'}

# %%
conjunto.add(1.2)
conjunto
# Out:
# {0, 1, 1.2, 10, 2, 20, 3, 4, 'b', 'c', 'h', 'x', 'z'}

# %%
grupo = {'Hector', 'Juan', 'Mario'}

# %%
'Hector' in grupo
# Out:
# True

# %%
'Freddy' in grupo
# Out:
# False

# %%
'Hector' not in grupo
# Out:
# False

# %%
test = {'Hector', 'Hector', 'Hector'}

# %%
test
# Out:
# {'Hector'}

# %%
lista = [ 1,2,1,1,3,4,5,2,2,3]
lista
# Out:
# [1, 2, 1, 1, 3, 4, 5, 2, 2, 3]

# %%
tup = set(lista)

# %%
tup
# Out:
# {1, 2, 3, 4, 5}

# %%
lista2 = list(tup)
lista2
# Out:
# [1, 2, 3, 4, 5]

# %%
l = [1,2,3,3,2,1]

# %%
l = list(set(l))
l
# Out:
# [1, 2, 3]

# %%
s = "Al pan pan y al vino vino"
set(s)
# Out:
# {' ', 'A', 'a', 'i', 'l', 'n', 'o', 'p', 'v', 'y'}

# %%
conjunto = set()

# %%
conjunto
# Out:
# set()

# %%
conjunto = {1,2,3}
conjunto
# Out:
# {1, 2, 3}

# %%
conjunto.add(4)

# %%
conjunto
# Out:
# {1, 2, 3, 4}

# %%
conjunto.add(0)

# %%
conjunto
# Out:
# {0, 1, 2, 3, 4}

# %%
conjunto.add('H')

# %%
conjunto
# Out:
# {0, 1, 2, 3, 4, 'H'}

# %%
conjunto.add('A')

# %%
conjunto.add('Z')

# %%
conjunto
# Out:
# {0, 1, 2, 3, 4, 'A', 'H', 'Z'}

# %%
conjunto.add('B')
conjunto
# Out:
# {0, 1, 2, 3, 4, 'A', 'B', 'H', 'Z'}

# %%
grupo = {'Hector','Juan', 'Mario'}

# %%
'Hector' in grupo
# Out:
# True

# %%
'Maria' in grupo
# Out:
# False

# %%
'Hector' not in grupo
# Out:
# False

# %%
test = {'Hector', 'Hector','Hector'}

# %%
test
# Out:
# {'Hector'}

# %%
l = [1,2,3,3,2,1]
l
# Out:
# [1, 2, 3, 3, 2, 1]

# %%
c = set(l)

# %%
c
# Out:
# {1, 2, 3}

# %%
l = list(c)

# %%
l
# Out:
# [1, 2, 3]

# %%
l = [1,2,3,3,2,1]

# %%
for i,j in enumerate(l):
    print(l[i])
# Out:
# 1
# 2
# 3
# 3
# 2
# 1

# %%
l = list(set(l))

# %%
l
# Out:
# [1, 2, 3]

# %%
s = "Al pan pan y al vino vino"
set(s)
# Out:
# {' ', 'A', 'a', 'i', 'l', 'n', 'o', 'p', 'v', 'y'}

# %%
conjunto = {2,4,6,8,10,12}

# %%
conjunto
# Out:
# {2, 4, 6, 8, 10, 12}

# %%
for i,j in enumerate(conjunto):
    print(conjunto[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-63251cc9dde8> in <module>
#       1 for i,j in enumerate(conjunto):
# ----> 2     print(conjunto[i])
#
# TypeError: 'set' object is not subscriptable
