# %%
pila = [3,4,5]

# %%
pila.append(6)

# %%
pila.append(7)

# %%
pila
# Out:
# [3, 4, 5, 6, 7]

# %%
pila.pop()
# Out:
# 7

# %%
pila
# Out:
# [3, 4, 5, 6]

# %%
n = pila.pop()

# %%
n
# Out:
# 6

# %%
pila
# Out:
# [3, 4, 5]

# %%
pila.pop()
pila.pop()
pila.pop()
# Out:
# 3

# %%
pila
# Out:
# []

# %%
pila.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-73c5ba2ac2af> in <module>
# ----> 1 pila.pop()
#
# IndexError: pop from empty list

# %%
from collections import deque

# %%
cola = deque()

# %%
cola
# Out:
# deque([])

# %%
cola = deque(['Hector', 'Juan', 'Miguel'])

# %%
cola
# Out:
# deque(['Hector', 'Juan', 'Miguel'])

# %%
cola[1]
# Out:
# 'Juan'

# %%
cola.append('Maria')

# %%
cola.append('Arnaldo')

# %%
cola
# Out:
# deque(['Hector', 'Juan', 'Miguel', 'Maria', 'Arnaldo'])

# %%
cola.popleft()
# Out:
# 'Hector'

# %%
cola
# Out:
# deque(['Juan', 'Miguel', 'Maria', 'Arnaldo'])

# %%
p = cola.popleft()

# %%
p
# Out:
# 'Juan'

# %%
cola
# Out:
# deque(['Miguel', 'Maria', 'Arnaldo'])

# %%
for v in cola:
    print(v)
# Out:
# Miguel
# Maria
# Arnaldo

# %%
pila = [3,4,5]

# %%
pila.append(6)

# %%
pila.append(7)

# %%
pila
# Out:
# [3, 4, 5, 6, 7]

# %%
pila.pop()
# Out:
# 7

# %%
pila
# Out:
# [3, 4, 5, 6]

# %%
n = pila.pop()

# %%
n
# Out:
# 6

# %%
pila
# Out:
# [3, 4, 5]

# %%
pila.pop()
pila.pop()
pila.pop()
# Out:
# 3

# %%
pila
# Out:
# []

# %%
from collections import deque

# %%
cola = deque()

# %%
cola
# Out:
# deque([])

# %%
cola = deque(['Hector','Juan','Miguel'])

# %%
cola
# Out:
# deque(['Hector', 'Juan', 'Miguel'])

# %%
cola.append('Maria')
cola.append('Arnaldo')

# %%
cola
# Out:
# deque(['Hector', 'Juan', 'Miguel', 'Maria', 'Arnaldo'])

# %%
cola.popleft()
# Out:
# 'Hector'

# %%
cola
# Out:
# deque(['Juan', 'Miguel', 'Maria', 'Arnaldo'])

# %%
p = cola.popleft()

# %%
cola
# Out:
# deque(['Miguel', 'Maria', 'Arnaldo'])

# %%
p
# Out:
# 'Juan'

# %%
d = {"nombre":"Juan", "edad": 50 }
d["apellido"] = "Perez"
d["edad"] += 4
 
print( d["nombre"], d["apellido"], d["edad"] )
print(d)
# Out:
# Juan Perez 54
# {'nombre': 'Juan', 'edad': 54, 'apellido': 'Perez'}
