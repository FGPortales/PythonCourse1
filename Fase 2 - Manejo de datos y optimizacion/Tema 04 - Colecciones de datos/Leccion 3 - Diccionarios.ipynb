# %%
vacio = {}
vacio
# Out:
# {}

# %%
type(vacio)
# Out:
# dict

# %%
colores = {'amarillo': 'yellow', 'azul': 'blue', 'verde': 'green'}

# %%
colores
# Out:
# {'amarillo': 'yellow', 'azul': 'blue', 'verde': 'green'}

# %%
colores['morado'] = 'purple'
colores
# Out:
# {'amarillo': 'yellow', 'azul': 'blue', 'verde': 'green', 'morado': 'purple'}

# %%
colores['morado'] = 'ya no purple'
colores
# Out:
# {'amarillo': 'yellow',
#  'azul': 'blue',
#  'verde': 'green',
#  'morado': 'ya no purple'}

# %%
colores['azul']
# Out:
# 'blue'

# %%
colores['amarillo']
# Out:
# 'yellow'

# %%
for i in colores:
    print(f"{i} = {colores[i]}")
# Out:
# amarillo = yellow
# azul = blue
# verde = green

# %%
edades = {'Hector': 27, 'Juan': 45, 'Maria': 34}
edades['Hector']
# Out:
# 27

# %%
edades
# Out:
# {'Hector': 27, 'Juan': 45, 'Maria': 34}

# %%
edades['Hector'] += 1

# %%
edades
# Out:
# {'Hector': 28, 'Juan': 45, 'Maria': 34}

# %%
edades['Juan'] + edades['Maria']
# Out:
# 79

# %%
for c, v in edades.items():
    print(c,v)
# Out:
# Hector 28
# Juan 45
# Maria 34

# %%
edades.items()
# Out:
# dict_items([('Hector', 28), ('Juan', 45), ('Maria', 34)])

# %%
personajes = []

# %%
p = {'Nombre': 'Gandalf', 'Clase': 'Mago', 'Raza': 'Humano'}

# %%
personajes.append(p)

# %%
personajes
# Out:
# [{'Nombre': 'Gandalf', 'Clase': 'Mago', 'Raza': 'Humano'}]

# %%
p = {'Nombre': 'Legolas', 'Clase': 'Arquero', 'Raza': 'Elfo'}

# %%
personajes.append(p)

# %%
p = {'Nombre': 'Gimil', 'Clase': 'Guerrero', 'Raza': 'Enano'}

# %%
personajes.append(p)

# %%
personajes
# Out:
# [{'Nombre': 'Gandalf', 'Clase': 'Mago', 'Raza': 'Humano'},
#  {'Nombre': 'Legolas', 'Clase': 'Arquero', 'Raza': 'Elfo'},
#  {'Nombre': 'Gimil', 'Clase': 'Guerrero', 'Raza': 'Enano'}]

# %%
for indice,valor in enumerate(personajes):
    for c,v in personajes[indice].items():
        print(f"{c}: {v} - ", end = " ")
    print("")
# Out:
# Nombre: Gandalf -  Clase: Mago -  Raza: Humano -
# Nombre: Legolas -  Clase: Arquero -  Raza: Elfo -
# Nombre: Gimil -  Clase: Guerrero -  Raza: Enano -

# %%
vacio = {}

# %%
vacio
# Out:
# {}

# %%
type(vacio)
# Out:
# dict

# %%
colores = {'amarillo': 'yellow', 'azul': 'blue', 'verde': 'green'}

# %%
colores
# Out:
# {'amarillo': 'yellow', 'azul': 'blue', 'verde': 'green'}

# %%
colores['azul']
# Out:
# 'blue'

# %%
colores['amarillo']
# Out:
# 'yellow'

# %%
numeros = {10:'diez', 20:'veinte'}

# %%
numeros[10]
# Out:
# 'diez'

# %%
numeros[20]
# Out:
# 'veinte'

# %%
colores['amarillo'] = 'white'

# %%
colores
# Out:
# {'amarillo': 'white', 'azul': 'blue', 'verde': 'green'}

# %%
del(colores['amarillo'])

# %%
colores
# Out:
# {'azul': 'blue', 'verde': 'green'}

# %%
edades = {'Hector': 27, 'Juan': 45, 'Maria': 34}

# %%
edades
# Out:
# {'Hector': 27, 'Juan': 45, 'Maria': 34}

# %%
edades['Hector'] += 1

# %%
edades
# Out:
# {'Hector': 28, 'Juan': 45, 'Maria': 34}

# %%
edades['Juan'] + edades['Maria']
# Out:
# 79

# %%
for edad in edades:
    print(edad)
# Out:
# Hector
# Juan
# Maria

# %%
for clave in edades:
    print(edades[clave])
# Out:
# 28
# 45
# 34

# %%
for clave in edades:
    print(clave, edades[clave])
# Out:
# Hector 28
# Juan 45
# Maria 34

# %%
for clave, valor in edades.items():
    print(clave,valor)
# Out:
# Hector 28
# Juan 45
# Maria 34

# %%
personajes = []

# %%
p = {'Nombre':'Gandalf', 'Clase':'Mago', 'Raza':'Humano'}

# %%
personajes.append(p)

# %%
personajes
# Out:
# [{'Nombre': 'Gandalf', 'Clase': 'Mago', 'Raza': 'Humano'}]

# %%
p = {'Nombre':'Legolas', 'Clase':'Arquero', 'Raza':'Elfo'}

# %%
personajes.append(p)

# %%
p = {'Nombre':'Gimli', 'Clase':'Guerrero', 'Raza':'Enano'}

# %%
personajes.append(p)

# %%
personajes
# Out:
# [{'Nombre': 'Gandalf', 'Clase': 'Mago', 'Raza': 'Humano'},
#  {'Nombre': 'Legolas', 'Clase': 'Arquero', 'Raza': 'Elfo'},
#  {'Nombre': 'Gimli', 'Clase': 'Guerrero', 'Raza': 'Enano'}]

# %%
for p in personajes:
    print(p['Nombre'],p['Clase'],p['Raza'])
# Out:
# Gandalf Mago Humano
# Legolas Arquero Elfo
# Gimli Guerrero Enano
